# %% [markdown]
# ## Aquarion Water Co Of Ct-Main System

# %%
import pandas as pd

# Define the mapping for the 'building type' column.
mapping = {
    'sf': 'Single-Family Residence',
    'mf': 'Multi-Family Residence',
    'sch_cc': 'School/Child Care',
    'res_cc': 'Residential & In-Home Child Care',
    'nonres': 'Nonresidential, Non-School, Non-Daycare',
    'mix': 'Mixed Residential & Nonresidential',
    'o': 'Other'
}

# Load the CSV file.
df = pd.read_csv('Aquarion_Water_Co_geocoded.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('Aquarion_Water_Co_geocoded_titlecase.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 15
#       4 mapping = {
#       5     'sf': 'Single-Family Residence',
#       6     'mf': 'Multi-Family Residence',
#    (...)
#      11     'o': 'Other'
#      12 }
#      14 # Load the CSV file.
# ---> 15 df = pd.read_csv('Aquarion_Water_Co_geocoded.csv')
#      17 # Process the 'building type' column:
#      18 #   - Convert each value to lowercase for matching.
#      19 #   - If the key is found in the mapping, substitute with the mapped value.
#      20 #   - Otherwise, convert the original value to title-case.
#      21 df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
#      22     lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
#      23 )
#
# File /usr/local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /usr/local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /usr/local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /usr/local/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Aquarion_Water_Co_geocoded.csv'

# %% [markdown]
# ## Windham Water Works

# %%
# Load the CSV file.
df = pd.read_csv('Windham_Water_Works_geocoded.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('Windham_Water_Works_geocoded_titlecase.csv', index=False)
# Out:
#    SITE ID LOCATION IDENTIFIER   STREET ADDRESS     TOWN  \
# 0    40418     41.708, -72.206       27 Park St  Windham
# 1    30329       41.706, -72.2   217 Windham Rd  Windham
# 2    20521     41.718, -72.213  118 Chestnut St  Windham
# 3    20959     41.717, -72.215    150 Walnut St  Windham
# 4    20317     41.716, -72.193  348 Bricktop Rd  Windham
#
#                merged address STATE  \
# 0       27 Park St Windham Ct    Ct
# 1   217 Windham Rd Windham Ct    Ct
# 2  118 Chestnut St Windham Ct    Ct
# 3    150 Walnut St Windham Ct    Ct
# 4  348 Bricktop Rd Windham Ct    Ct
#
#   ENTIRE SERVICE LINE MATERIAL CLASSIFICATION            BUILDING TYPE  \
# 0                                        Lead   Multi-Family Residence
# 1                                        Lead  Single-Family Residence
# 2                                        Lead  Single-Family Residence
# 3                                        Lead  Single-Family Residence
# 4                                        Lead   Multi-Family Residence
#
#                                       SOURCE FILE  STREET NUMBER  STREET NAME  \
# 0  Ct1630011_Lcrr_Inventory_Initial_10-11-24.Xlsx            NaN          NaN
# 1  Ct1630011_Lcrr_Inventory_Initial_10-11-24.Xlsx            NaN          NaN
# 2  Ct1630011_Lcrr_Inventory_Initial_10-11-24.Xlsx            NaN          NaN
# 3  Ct1630011_Lcrr_Inventory_Initial_10-11-24.Xlsx            NaN          NaN
# 4  Ct1630011_Lcrr_Inventory_Initial_10-11-24.Xlsx            NaN          NaN
#
#   extracted_pswid  is_match      PWSID          SYSTEM NAME        lat  \
# 0       Ct1630011      True  Ct1630011  Windham Water Works  41.708061
# 1       Ct1630011      True  Ct1630011  Windham Water Works  41.706462
# 2       Ct1630011      True  Ct1630011  Windham Water Works  41.718198
# 3       Ct1630011      True  Ct1630011  Windham Water Works  41.716745
# 4       Ct1630011      True  Ct1630011  Windham Water Works  41.716078
#
#         long
# 0 -72.206050
# 1 -72.200314
# 2 -72.212653
# 3 -72.214548
# 4 -72.193234

# %% [markdown]
# ## All water systems

# %%
# Load the CSV file.
df = pd.read_csv('all-lead.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('all-lead_titlecase.csv', index=False)
# Out:
#   SITE ID  STREET ADDRESS           TOWN STATE  \
# 0   48817    53 Circle Dr  Windsor Locks    Ct
# 1   49498  421 Denslow St  Windsor Locks    Ct
# 2   49732    46 Center St  Windsor Locks    Ct
# 3   51893   154 Sunset St  Windsor Locks    Ct
# 4   59967    754 Avery St  South Windsor    Ct
#
#   ENTIRE SERVICE LINE MATERIAL CLASSIFICATION            BUILDING TYPE  \
# 0                                        Lead  Single-Family Residence
# 1                                        Lead  Single-Family Residence
# 2                                        Lead  Single-Family Residence
# 3                                        Lead  Single-Family Residence
# 4                                        Lead  Single-Family Residence
#
#        PWSID                         SYSTEM NAME  Unnamed: 8  Unnamed: 9  \
# 0  Ct0473011  Ctwc - Northern Reg-Western System         NaN         NaN
# 1  Ct0473011  Ctwc - Northern Reg-Western System         NaN         NaN
# 2  Ct0473011  Ctwc - Northern Reg-Western System         NaN         NaN
# 3  Ct0473011  Ctwc - Northern Reg-Western System         NaN         NaN
# 4  Ct0473011  Ctwc - Northern Reg-Western System         NaN         NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ## Waterbury Water Department

# %%
# Define the mapping for the 'building type' column.
mapping = {
    'sf': 'Single-Family Residence',
    'mf': 'Multi-Family Residence',
    'sch_cc': 'School/Child Care',
    'res_cc': 'Residential & In-Home Child Care',
    'nonres': 'Nonresidential, Non-School, Non-Daycare',
    'mix': 'Mixed Residential & Nonresidential',
    'o': 'Other'
}

# Load the CSV file.
df = pd.read_csv('Waterbury_Water_Department_geocoded.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('Waterbury_Water_Department_geocoded_titlecase.csv', index=False)
# Out:
#    SITE ID      STREET ADDRESS       TOWN  \
# 0   102148      120 Easton Ave  Waterbury
# 1   102618        107 Platt St  Waterbury
# 2   103178  1089 North Main St  Waterbury
# 3   103188  1063 North Main St  Waterbury
# 4   103208  1043 North Main St  Waterbury
#
#                              merged address        STATE  \
# 0      120 Easton Ave Waterbury Connecticut  Connecticut
# 1        107 Platt St Waterbury Connecticut  Connecticut
# 2  1089 North Main St Waterbury Connecticut  Connecticut
# 3  1063 North Main St Waterbury Connecticut  Connecticut
# 4  1043 North Main St Waterbury Connecticut  Connecticut
#
#   ENTIRE SERVICE LINE MATERIAL CLASSIFICATION            BUILDING TYPE  \
# 0                                        Lead   Multi-Family Residence
# 1                                        Lead  Single-Family Residence
# 2                                        Lead   Multi-Family Residence
# 3                                        Lead                    Other
# 4                                        Lead   Multi-Family Residence
#
#        PWSID                 SYSTEM NAME        lat       long
# 0  Ct1510011  Waterbury Water Department  41.566187 -73.030324
# 1  Ct1510011  Waterbury Water Department  41.567653 -73.030817
# 2  Ct1510011  Waterbury Water Department  41.566610 -73.027898
# 3  Ct1510011  Waterbury Water Department  41.566395 -73.028237
# 4  Ct1510011  Waterbury Water Department  41.566395 -73.028760

# %% [markdown]
# ## New London Dept. of Public Utilities

# %%
mapping = {
    'sf': 'Single-Family Residence',
    'mf': 'Multi-Family Residence',
    'sch_cc': 'School/Child Care',
    'res_cc': 'Residential & In-Home Child Care',
    'nonres': 'Nonresidential, Non-School, Non-Daycare',
    'mix': 'Mixed Residential & Nonresidential',
    'o': 'Other'
}
# Load the CSV file.
df = pd.read_csv('New_London_geocoded.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('New_London_geocoded_titlecase.csv', index=False)
# Out:
#       SITE ID  STREET ADDRESS        TOWN                merged address STATE  \
# 0   6 - 40620     1 Colver St  New London     1 Colver St New London Ct    Ct
# 1  63 - 38321     10 Lyman Ct  New London     10 Lyman Ct New London Ct    Ct
# 2  75 - 38501  10 Rosemary St  New London  10 Rosemary St New London Ct    Ct
# 3  94 - 38859   100 School St  New London   100 School St New London Ct    Ct
# 4  99 - 40630  1000 Ocean Ave  New London  1000 Ocean Ave New London Ct    Ct
#
#   ENTIRE SERVICE LINE MATERIAL CLASSIFICATION     BUILDING TYPE      PWSID  \
# 0                                        Lead  Residential (Sf)  Ct0950011
# 1                                        Lead  Residential (Sf)  Ct0950011
# 2                                        Lead        Commercial  Ct0950011
# 3                                        Lead           Unknown  Ct0950011
# 4                                        Lead           Unknown  Ct0950011
#
#                             SYSTEM NAME        lat       long
# 0  New London Dept. Of Public Utilities  41.354586 -72.111793
# 1  New London Dept. Of Public Utilities  41.527269 -72.108959
# 2  New London Dept. Of Public Utilities  41.365892 -72.101046
# 3  New London Dept. Of Public Utilities  41.333981 -72.103774
# 4  New London Dept. Of Public Utilities  41.315868 -72.097316

# %% [markdown]
# ## Aquarion Water Co of CT-Greenwich

# %%
mapping = {
    'sf': 'Single-Family Residence',
    'mf': 'Multi-Family Residence',
    'sch_cc': 'School/Child Care',
    'res_cc': 'Residential & In-Home Child Care',
    'nonres': 'Nonresidential, Non-School, Non-Daycare',
    'mix': 'Mixed Residential & Nonresidential',
    'o': 'Other'
}
# Load the CSV file.
df = pd.read_csv('Aquarion_Greenwich_geocoded.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('Aquarion_Greenwich_geocoded_titlecase.csv', index=False)
# Out:
#      SITE ID     STREET ADDRESS     TOWN                merged address STATE  \
# 0  700152103        9 Tingue St    Byram          9 Tingue St Byram Ct    Ct
# 1  700164929  223 Cognewaugh Rd  Cos Cob  223 Cognewaugh Rd Cos Cob Ct    Ct
# 2  700224686       48 Valley Rd  Cos Cob       48 Valley Rd Cos Cob Ct    Ct
# 3  700148694        30 River Rd  Cos Cob        30 River Rd Cos Cob Ct    Ct
# 4  700148819         8 Miami Ct  Cos Cob         8 Miami Ct Cos Cob Ct    Ct
#
#   ENTIRE SERVICE LINE MATERIAL CLASSIFICATION            BUILDING TYPE  \
# 0                                        Lead   Multi-Family Residence
# 1                                        Lead  Single-Family Residence
# 2                                        Lead  Single-Family Residence
# 3                                        Lead  Single-Family Residence
# 4                                        Lead  Single-Family Residence
#
#        PWSID                        SYSTEM NAME        lat       long
# 0  Ct0570011  Aquarion Water Co Of Ct-Greenwich  41.002723 -73.651930
# 1  Ct0570011  Aquarion Water Co Of Ct-Greenwich        NaN        NaN
# 2  Ct0570011  Aquarion Water Co Of Ct-Greenwich  41.042464 -73.593332
# 3  Ct0570011  Aquarion Water Co Of Ct-Greenwich  41.035945 -73.595601
# 4  Ct0570011  Aquarion Water Co Of Ct-Greenwich  41.038828 -73.595872

# %% [markdown]
# ## Middletown Water Department

# %%
mapping = {
    'sf': 'Single-Family Residence',
    'mf': 'Multi-Family Residence',
    'sch_cc': 'School/Child Care',
    'res_cc': 'Residential & In-Home Child Care',
    'nonres': 'Nonresidential, Non-School, Non-Daycare',
    'mix': 'Mixed Residential & Nonresidential',
    'o': 'Other'
}
# Load the CSV file.
df = pd.read_csv('Middletown_geocoded.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('Middletown_geocoded_titlecase.csv', index=False)
# Out:
#      SITE ID    STREET ADDRESS        TOWN                  merged address  \
# 0  00000007R   353 Main Street  Middletown   353 Main Street Middletown Ct
# 1  00000032C   291 Main Street  Middletown   291 Main Street Middletown Ct
# 2  00000042R  241 Court Street  Middletown  241 Court Street Middletown Ct
# 3  00000050R   346 Main Street  Middletown   346 Main Street Middletown Ct
# 4  00000071R   318 Main Street  Middletown   318 Main Street Middletown Ct
#
#   STATE ENTIRE SERVICE LINE MATERIAL CLASSIFICATION  \
# 0    Ct                                        Lead
# 1    Ct                                        Lead
# 2    Ct                                        Lead
# 3    Ct                                        Lead
# 4    Ct                                        Lead
#
#                              BUILDING TYPE      PWSID  \
# 0  Nonresidential, Non-School, Non-Daycare  Ct0830011
# 1  Nonresidential, Non-School, Non-Daycare  Ct0830011
# 2                   Multi-Family Residence  Ct0830011
# 3  Nonresidential, Non-School, Non-Daycare  Ct0830011
# 4  Nonresidential, Non-School, Non-Daycare  Ct0830011
#
#                    SYSTEM NAME        lat       long
# 0  Middletown Water Department  41.560982 -72.650711
# 1  Middletown Water Department  41.560164 -72.650103
# 2  Middletown Water Department  41.559130 -72.652837
# 3  Middletown Water Department  41.561150 -72.649841
# 4  Middletown Water Department  41.560833 -72.649580

# %% [markdown]
# ## Meriden Water Division

# %%
mapping = {
    'sf': 'Single-Family Residence',
    'mf': 'Multi-Family Residence',
    'sch_cc': 'School/Child Care',
    'res_cc': 'Residential & In-Home Child Care',
    'nonres': 'Nonresidential, Non-School, Non-Daycare',
    'mix': 'Mixed Residential & Nonresidential',
    'o': 'Other'
}
# Load the CSV file.
df = pd.read_csv('Meriden Water Division.csv')

# Process the 'building type' column:
#   - Convert each value to lowercase for matching.
#   - If the key is found in the mapping, substitute with the mapped value.
#   - Otherwise, convert the original value to title-case.
df['BUILDING TYPE'] = df['BUILDING TYPE'].apply(
    lambda x: mapping.get(x.lower(), x.title()) if isinstance(x, str) else x
)

# Process all other object type (string) columns by converting them to title-case.
for col in df.select_dtypes(include=['object']):
    if col != 'building type':
        df[col] = df[col].apply(lambda x: x.title() if isinstance(x, str) else x)

# (Optional) Check the first few rows to confirm the transformation.
print(df.head())

# Save the modified DataFrame to a new CSV file.
df.to_csv('Meriden_titlecase.csv', index=False)
# Out:
#    SITE ID        lat       long   STREET ADDRESS     TOWN  \
# 0   113440  41.528686 -72.783580    84 Dexter Ave  Meriden
# 1   113442  41.548668 -72.795772    96 Wilcox Ave  Meriden
# 2   113444  41.538271 -72.816065   62 Bradley Ave  Meriden
# 3   113446  41.546385 -72.821026  70 Corrigan Ave  Meriden
# 4   113448  41.520925 -72.829614     42 Meadow St  Meriden
#
#                merged address STATE  \
# 0    84 Dexter Ave Meriden Ct    Ct
# 1    96 Wilcox Ave Meriden Ct    Ct
# 2   62 Bradley Ave Meriden Ct    Ct
# 3  70 Corrigan Ave Meriden Ct    Ct
# 4     42 Meadow St Meriden Ct    Ct
#
#   ENTIRE SERVICE LINE MATERIAL CLASSIFICATION            BUILDING TYPE  \
# 0                         Lead Status Unknown  Single-Family Residence
# 1                         Lead Status Unknown  Single-Family Residence
# 2                         Lead Status Unknown  Single-Family Residence
# 3                         Lead Status Unknown  Single-Family Residence
# 4                         Lead Status Unknown  Single-Family Residence
#
#                                       SOURCE FILE  STREET NUMBER  STREET NAME  \
# 0  Ct0800011_Lcrr_Inventory_Initial_10.15.24.Xlsx            NaN          NaN
# 1  Ct0800011_Lcrr_Inventory_Initial_10.15.24.Xlsx            NaN          NaN
# 2  Ct0800011_Lcrr_Inventory_Initial_10.15.24.Xlsx            NaN          NaN
# 3  Ct0800011_Lcrr_Inventory_Initial_10.15.24.Xlsx            NaN          NaN
# 4  Ct0800011_Lcrr_Inventory_Initial_10.15.24.Xlsx            NaN          NaN
#
#   extracted_pswid  is_match      PWSID             SYSTEM NAME
# 0       Ct0800011      True  Ct0800011  Meriden Water Division
# 1       Ct0800011      True  Ct0800011  Meriden Water Division
# 2       Ct0800011      True  Ct0800011  Meriden Water Division
# 3       Ct0800011      True  Ct0800011  Meriden Water Division
# 4       Ct0800011      True  Ct0800011  Meriden Water Division
